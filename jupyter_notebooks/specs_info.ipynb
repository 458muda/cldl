# %%
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('To enable a high-RAM runtime, select the Runtime > "Change runtime type"')
  print('menu, and then select High-RAM in the Runtime shape dropdown. Then, ')
  print('re-execute this cell.')
else:
  print('You are using a high-RAM runtime!')

gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Select the Runtime > "Change runtime type" menu to enable a GPU accelerator, ')
  print('and then re-execute this cell.')
else:
  print(gpu_info)
# Out:
# Your runtime has 540.7 gigabytes of available RAM
#
# You are using a high-RAM runtime!
# Fri Aug 19 19:25:49 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 510.85.02    Driver Version: 510.85.02    CUDA Version: 11.6     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Quadro RTX 5000     Off  | 00000000:1A:00.0 Off |                  Off |
# | 47%   71C    P2   225W / 230W |    123MiB / 16384MiB |    100%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   1  Quadro RTX 5000     Off  | 00000000:1C:00.0 Off |                  Off |
# | 53%   76C    P2   234W / 230W |    123MiB / 16384MiB |    100%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   2  Quadro RTX 5000     Off  | 00000000:1D:00.0 Off |                  Off |
# | 49%   73C    P2   230W / 230W |    123MiB / 16384MiB |    100%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   3  Quadro RTX 5000     Off  | 00000000:1E:00.0 Off |                  Off |
# | 46%   70C    P2   230W / 230W |    123MiB / 16384MiB |    100%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   4  Quadro RTX 5000     Off  | 00000000:3D:00.0 Off |                  Off |
# | 33%   30C    P8    11W / 230W |      8MiB / 16384MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   5  Quadro RTX 5000     Off  | 00000000:3F:00.0 Off |                  Off |
# | 33%   31C    P8    20W / 230W |      8MiB / 16384MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   6  Quadro RTX 5000     Off  | 00000000:40:00.0 Off |                  Off |
# | 33%   35C    P2    50W / 230W |  15299MiB / 16384MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   7  Quadro RTX 5000     Off  | 00000000:41:00.0 Off |                  Off |
# | 33%   32C    P8    12W / 230W |      8MiB / 16384MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A      5584      G   /usr/lib/xorg/Xorg                  4MiB |
# |    0   N/A  N/A      7669      C   ./dnetc                           115MiB |
# |    1   N/A  N/A      5584      G   /usr/lib/xorg/Xorg                  4MiB |
# |    1   N/A  N/A      7669      C   ./dnetc                           115MiB |
# |    2   N/A  N/A      5584      G   /usr/lib/xorg/Xorg                  4MiB |
# |    2   N/A  N/A      7669      C   ./dnetc                           115MiB |
# |    3   N/A  N/A      5584      G   /usr/lib/xorg/Xorg                  4MiB |
# |    3   N/A  N/A      7669      C   ./dnetc                           115MiB |
# |    4   N/A  N/A      5584      G   /usr/lib/xorg/Xorg                  4MiB |
# |    5   N/A  N/A      5584      G   /usr/lib/xorg/Xorg                  4MiB |
# |    6   N/A  N/A      5584      G   /usr/lib/xorg/Xorg                  4MiB |
# |    6   N/A  N/A    290357      C   ...nda3/envs/cldl/bin/python    15291MiB |
# |    7   N/A  N/A      5584      G   /usr/lib/xorg/Xorg                  4MiB |
# +-----------------------------------------------------------------------------+
